# %% [markdown]
# <a href="https://colab.research.google.com/github/FaiqFadhlurrahmanElHakim/MachineLearning/blob/main/1197050038_Faiq_Fadhlurrahman_El_Hakim_D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = '/exchange_rate_to_usd.csv'
df = pd.read_csv(data)

# %%
df.head()
# Out:
#          date  chinese_yuan_to_usd  euro_to_usd  japanese_yen_to_usd  \
# 0  2004-01-02                  NaN     0.794155                  NaN
# 1  2004-01-05             0.120817     0.790077             0.009355
# 2  2004-01-06             0.120815     0.783945             0.009412
# 3  2004-01-07             0.120814     0.788706             0.009413
# 4  2004-01-08             0.120814     0.791515             0.009421
#
#    uk_pound_to_usd  us_dollar_to_usd  algerian_dinar_to_usd  \
# 0         0.559973               1.0                    NaN
# 1         0.555679               1.0                    NaN
# 2         0.549179               1.0                    NaN
# 3         0.551268               1.0                    NaN
# 4         0.551815               1.0                    NaN
#
#    australian_dollar_to_usd  bahrain_dinar_to_usd  botswana_pula_to_usd  ...  \
# 0                  1.328551              2.659574                   NaN  ...
# ...
